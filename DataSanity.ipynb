# %%
import pandas as pd

# %%
pd.options.display.max_rows = 1000

# %%
offence_master = pd.read_excel('Data Storage/MorthDataSets/TBL_TR_Offence_Master.xlsx')

# %%
offence_details = pd.read_excel('Data Storage/MorthDataSets/TBL_TR_Offence_details.xlsx')

# %%
offence_details.head()
# Out:
#    Unit_ID  Offence_Place        Offence_Date Registration_Number  \
# 0     1472     2011000008 2013-12-27 11:55:00        KA 24 S 4161
# 1     1509     2013000002 2013-11-21 15:38:00          KA04 S2547
# 2      350     2012000002 2014-02-12 05:40:00           KA28K5993
# 3      227     2011000006 2017-09-23 12:27:00           KA02W9469
# 4      297     2011000014 2013-06-27 11:30:00        KA 22 J 7637
#
#    Vehicle_Type_ID  Owner_PersonID  Driver_PersonID  Police_Station_ID  \
# 0             4147      2014000009       2014000010                NaN
# 1             4149      2013000845       2013000846                NaN
# 2             4147      2014000169       2014000170                NaN
# 3             4147      2017007249       2017007250                NaN
# 4             4147      2013000757       2013000758                NaN
#
#   Notice_Number Conductor_Name           ...           CC_No Court_Details  \
# ...

# %%
offence_details.columns
# Out:
# Index(['Unit_ID', 'Offence_Place', 'Offence_Date', 'Registration_Number',
#        'Vehicle_Type_ID', 'Owner_PersonID', 'Driver_PersonID',
#        'Police_Station_ID', 'Notice_Number', 'Conductor_Name', 'Permit_Number',
#        'Valid_Upto', 'Issued_By', 'Offence_Description', 'UserID', 'Flag',
#        'Book_No', 'Serial_No', 'Traffic_Point', 'Reciept_No',
#        'Immediate_Parking', 'Paid_Status', 'Breadth_Analysis', 'CC_No',
#        'Court_Details', 'Fine_Paid_Date', 'Under_Aged', 'Modified_Unit_ID',
#        'Action_Flag', 'Sync_Id', 'Sync_Id_Old', 'Licence_Issued_By', 'DEDT'],
#       dtype='object')

# %%
cd Data\ Storage
# Out:
# /Users/khatribimal.mukesh/redBus/Learning/India Police Hackathon/Data Storage

# %%
tbl_CR_Victim_Info = pd.read_excel('MorthDataSets/tbl_tr_accident_report.xlsx')

# %%
tbl_CR_Victim_Info
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
# 30       NaN
# 31       NaN
# 32       NaN
# 33       NaN
# 34       NaN
# 35       NaN
# 36       NaN
# 37       NaN
# 38       NaN
# 39       NaN
# 40       NaN
# 41       NaN
# 42       NaN
# 43       NaN
# 44       NaN
# 45       NaN
# 46       NaN
# 47       NaN
# 48       NaN
# 49       NaN
# 50       NaN
# 51       NaN
# 52       NaN
# 53       NaN
# 54       NaN
# 55       NaN
# 56       NaN
# 57       NaN
# 58       NaN
# 59       NaN
# 60       NaN
# 61       NaN
# 62       NaN
# 63       NaN
# 64       NaN
# 65       NaN
# ...

# %%
location_list = tbl_CR_Victim_Info['Accident_Location'].unique()

# %%
import requests

# %%
final_location_list = []

# %%
for location in location_list:
    try:
        a = int(location)
        b = float(location)
    except Exception as e:
        final_location_list.append(location)

# %%
import requests

# %%
url = "https://api.opencagedata.com/geocode/v1/json?q={}&key=fc18af83c16446b99f3ad9d7fd5fcfd0".format(location + " Karnataka, India")

# %%
url
# Out:
# 'https://api.opencagedata.com/geocode/v1/json?q=K K Pharm frontKarnataka, India&key=fc18af83c16446b99f3ad9d7fd5fcfd0'

# %%
requests.get(url).json()
# Out:
# {'documentation': 'https://opencagedata.com/api',
#  'licenses': [{'name': 'see attribution guide',
#    'url': 'https://opencagedata.com/credits'}],
#  'rate': {'limit': 2500, 'remaining': 2496, 'reset': 1573948800},
#  'results': [{'annotations': {'DMS': {'lat': "22° 0' 0.00000'' N",
#      'lng': "79° 0' 0.00000'' E"},
#     'MGRS': '44QKK9352734177',
#     'Maidenhead': 'ML92ma00aa',
#     'Mercator': {'x': 8794239.773, 'y': 2495525.394},
#     'OSM': {'url': 'https://www.openstreetmap.org/?mlat=22.00000&mlon=79.00000#map=17/22.00000/79.00000'},
#     'UN_M49': {'regions': {'ASIA': '142',
#       'IN': '356',
#       'SOUTHERN_ASIA': '034',
#       'WORLD': '001'},
#      'statistical_groupings': ['LEDC']},
#     'callingcode': 91,
#     'currency': {'alternate_symbols': ['Rs', '৳', '૱', '௹', 'रु', '₨'],
#      'decimal_mark': '.',
#      'html_entity': '&#x20b9;',
#      'iso_code': 'INR',
#      'iso_numeric': '356',
#      'name': 'Indian Rupee',
# ...

# %%
FIR_details = pd.read_excel('MorthDataSets/tbl_CR_FIR_Details.xlsx')

# %%
sparse_df = FIR_details[['Address1','Address2','City','PIN_Code']]

# %%
FIR_details['State_ID'].value_counts()
# Out:
# 16    220052
# 19         9
# 2          9
# 29         3
# 15         3
# 10         2
# 34         1
# 11         1
# 5          1
# Name: State_ID, dtype: int64

# %%
master = pd.read_excel('MorthDataSets/Masters.xlsx',sheet_name='tbl_Unit_master')

# %%
master[master['District_ID'] == 443].columns
# Out:
# Index(['Unit_ID', 'Unit_Name', 'Unit_Head', 'Local_Name', 'Category_ID',
#        'Type_ID', 'Parent_Unit', 'Actual_Strength', 'Sanctioned_Strength',
#        'Taluk_ID', 'Address1', 'Address2', 'Zip', 'Phone', 'EMail', 'Fax',
#        'Nationality_ID', 'State_ID', 'District_ID', 'Active', 'UserID',
#        'Server_Unit', 'IsDDO_Unit', 'DDO_Code', 'Unit_Letter', 'Treasury_Code',
#        'Modified_Unit_ID', 'Action_Flag', 'Sync_Id', 'Sync_Id_Old'],
#       dtype='object')

# %%
location_mapping = sparse_df.merge(master[['District_ID','District_Name']], left_on = "City", right_on = 'District_ID', how='left')

# %%
master[['Address1','Address2']]
# Out:
#                                                Address1  \
# 0                                       Nrupatunga Road
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5         Yeshwantpura P.S. CV RAMAN ROAD, YESHWANTHPUR
# 6         DCP South Office, South End Circle, Jayanagar
# 7         CUBBON PARK PS PREMISES,KASTOORBA ROAD, CUBBO
# 8         NO.1, 1st Floor, Halasuru Police Station buil
# 9         Deputy Commissioner of Police, West Division,
# 10        R.M.C.Yard P.S. APMC YARD Building,1ST FLOOR
# 11        R.T.Nagar P.S. C.A No.8, 80 feet road, 1st Bo
# 12        Mahalakshmipura PS, No. CA-2,1ST FLOOR 2nd Ma
# 13        Jalahalli P.S. H.M.T Main, Road, Infront of H
# 14        Vidyaranyapura P.S. No.280, BEL, 6th block, 6
# 15          Office of the Asst. Commissioner of Police,
# ...

# %%
bangalore_data = location_mapping[location_mapping['District_Name'] == "Bengaluru City"]

# %%
bangalore_data['search_string'] = bangalore_data.apply(lambda x: str(x['Address1']) +' ' +str(x['Address2']) + ',Bangalore',axis=1)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
address_list = bangalore_data['search_string'].tolist()

# %%
address = address_list[0]

# %%
url = "https://geocode.xyz/{}?json=1".format(address)

# %%
resp = requests.get(url).json()

# %%
resp['latt'],resp['longt']
# Out:
# ('12.96062', '77.60087')

# %%
with_lat_long = pd.DataFrame()

# %%
import time
time.sleep(1)

# %%
count = 0

# %%
for index,row in bangalore_data[15183:].iterrows():
    try:
        count = count + 1
        print(count)
        address = row['search_string']
        url = "https://maps.googleapis.com/maps/api/geocode/json?address={}&key=AIzaSyA5qyM3gHn92xqV3Gnbenq7gOHQQwjufos".format(address)
        resp = requests.get(url).json()
        row['lat'] = resp['results'][0]['geometry']['location']['lat']
        row['long'] = resp['results'][0]['geometry']['location']['lng']
        with_lat_long = with_lat_long.append(row,ignore_index=True)
    except Exception as e:
        print(e)
# Out:
# 15184
# 15185
# 15186
# 15187
# 15188
# 15189
# 15190
# 15191
# 15192
# 15193
# 15194
# 15195
# 15196
# 15197
# 15198
# 15199
# 15200
# 15201
# 15202
# 15203
# 15204
# 15205
# 15206
# 15207
# 15208
# 15209
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-182-b7b8ad363759> in <module>()
#       5         address = row['search_string']
#       6         url = "https://maps.googleapis.com/maps/api/geocode/json?address={}&key=AIzaSyA5qyM3gHn92xqV3Gnbenq7gOHQQwjufos".format(address)
# ----> 7         resp = requests.get(url).json()
#       8         row['lat'] = resp['results'][0]['geometry']['location']['lat']
#       9         row['long'] = resp['results'][0]['geometry']['location']['lng']
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ...

# %%
resp = requests.get(url).json()

# %%
count
# Out:
# 6987

# %%
with_lat_long.iloc[5792]['search_string']
# Out:
# 'Near Kommagatta bridge, Nice road, towards Magadi Kengeri Hobali, Bangalore South Tq.,Bangalore'

# %%
resp
# Out:
# {'longt': '0.00000',
#  'matches': None,
#  'remaining_credits': '-302',
#  'error': {'description': '523019537006090350172x3943 has ran out of credits. 1',
#   'code': '002'},
#  'latt': '0.00000'}

# %%
resp['results'][0]['geometry']['location']
# Out:
# {'lat': 12.960033, 'lng': 77.6015405}

# %%
with_lat_long.to_csv('gmap1.csv',index=False)

# %%
address
# Out:
# 'MARKET ROAD BASAVANAGUDI,Bangalore'

# %%
resp
# Out:
# {'results': [{'address_components': [{'long_name': '9th Main Road',
#      'short_name': '9th Main Road',
#      'types': ['route']},
#     {'long_name': 'Thyagaraja Nagar',
#      'short_name': 'T R Nagar',
#      'types': ['political', 'sublocality', 'sublocality_level_2']},
#     {'long_name': 'Basavanagudi',
#      'short_name': 'Basavanagudi',
#      'types': ['political', 'sublocality', 'sublocality_level_1']},
#     {'long_name': 'Bengaluru',
#      'short_name': 'Bengaluru',
#      'types': ['locality', 'political']},
#     {'long_name': 'Bangalore Urban',
#      'short_name': 'Bangalore Urban',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'Karnataka',
#      'short_name': 'KA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'India',
#      'short_name': 'IN',
#      'types': ['country', 'political']},
#     {'long_name': '560070', 'short_name': '560070', 'types': ['postal_code']}],
# ...

# %%
with_lat_long.to_csv('FinalLatLong.csv',index=False)

# %%
bangalore_data
# Out:
#                                                  Address1  \
# 185                                       NANJAPPA CIRCLE
# 186           Near Krupanidhi Junction Sarjapur main road
# 187     S.Amrutha Kumari property,Serve No 18/8,27th c...
# 188                 NEAR NILAGIRIS FRESH, 29TH MAIN ROAD,
# 189                              NEAR LEDHAR ITALIYA SHOP
# 190                                         QUEENS CIRCLE
# 191                       K K  road,  shivananda junction
# 192                   11th CROSS 1st TEMPLE ROAD JUNCTION
# 193                                             J.C. ROAD
# 194            Outer Ring Road, Near Marathahalli Bridge,
# 195            PRAMENANDE  ROAD & CLEVELAND ROAD JUNCTION
# 196                                NEAR AYESHA POLYCLINIC
# 197         OLD MADRAS ROAD NEAR VIVEKANANDA METRO STAION
# 198                               AYYAPPA NAGAR MAIN ROAD
# 199                    Deconson Road, Near Webs Junction.
# ...

# %%
xx = FIR_details[['FIR_ID',"Unit_ID","Address1","Address2","City"]].copy(deep=True)

# %%
foo = xx.merge(with_lat_long,on=['Address1','Address2','City'],how='inner')

# %%
foo.to_csv('LatLongWithFIR.csv',index=False)

# %%
lat = 12.965619
long = 77.550676

# %%
url = "https://maps.googleapis.com/maps/api/geocode/json?latlng={},{}&key=AIzaSyA5qyM3gHn92xqV3Gnbenq7gOHQQwjufos".format(lat,long)

# %%
resp = requests.get(url).json()

# %%
area_name = resp['results'][0]['address_components'][0]['long_name']
